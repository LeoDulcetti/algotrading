# %%
import sys
import os

# Get the path to the src directory
src_path = os.path.abspath("/Users/lucazosso/Desktop/IE_Course/Term_3/Algorithmic_Trading/ie_mbd_sept23/sim/src")

# Add the src directory to the system path
if src_path not in sys.path:
    sys.path.append(src_path)

# Now you can import the OrdersDataset class
from prep_orders import OrdersDataset

# %%
orderbook_data_path = '/Users/lucazosso/Desktop/IE_Course/Term_3/Algorithmic_Trading/ie_mbd_sept23/sim/data/orderbook_data.csv'
message_data_path = '/Users/lucazosso/Desktop/IE_Course/Term_3/Algorithmic_Trading/ie_mbd_sept23/sim/data/message_data.csv'

data = OrdersDataset(orderbook_data_path, message_data_path)
data_prep = data.preprocessing()
# Out:
# Order data shape: (400391, 40)
# Message data shape: (400391, 6)

# %%
data_prep.head()
# Out:
#            Time  Type   OrderID  Size    Price         Direction  Ask Price 1  \
# 0  34200.004241     1  16113575    18  5853300   Buy limit order      5859400
# 1  34200.004261     1  16113584    18  5853200   Buy limit order      5859400
# 2  34200.004447     1  16113594    18  5853100   Buy limit order      5859400
# 3  34200.025552     1  16120456    18  5859100  Sell limit order      5859100
# 4  34200.025580     1  16120480    18  5859200  Sell limit order      5859100
#
#    Ask Size 1  Bid Price 1  Bid Size 1  ...  Ask Price 9  Ask Size 9  \
# 0         200      5853300          18  ...      5876500        1160
# 1         200      5853300          18  ...      5876500        1160
# 2         200      5853300          18  ...      5876500        1160
# 3          18      5853300          18  ...      5873900         100
# 4          18      5853300          18  ...      5871000          10
#
#    Bid Price 9  Bid Size 9  Ask Price 10  Ask Size 10  Bid Price 10  \
# ...
